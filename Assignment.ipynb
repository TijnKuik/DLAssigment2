# %% [markdown]
# What I did till now for the Sigmoid Function:
# - Added the sigmoid function to the value class. So that you can run the Sigmoid function of the value object.
# - Added the option to use or ReLU or Sigmoid Activation Function in the neuron class (removed self.lin) also edit the repr. class.
